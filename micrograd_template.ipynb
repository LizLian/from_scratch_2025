# %% [markdown]
# <a href="https://colab.research.google.com/github/LizLian/from_scratch_2025/blob/main/micrograd_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Micrograd
# 1. implement a Value class, where it takes another value object and does basic arithmetic operations (addition, subtraction, multiplication, division)
# 2. write a backward function that does back propagation. If you call o.backward(), the gradients will flow back and distribute to the nodes.
# (you can visualize the nodes using the draw_dot function)

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from graphviz import Digraph

def trace(root):
  # builds a set of all nodes and edges in a graph
  nodes, edges = set(), set()
  def build(v):
    if v not in nodes:
      nodes.add(v)
      for child in v._prev:
        edges.add((child, v))
        build(child)
  build(root)
  return nodes, edges

def draw_dot(root):
  dot = Digraph(format='svg', graph_attr={'rankdir': 'LR'}) # LR = left to right

  nodes, edges = trace(root)
  for n in nodes:
    uid = str(id(n))
    # for any value in the graph, create a rectangular ('record') node for it
    dot.node(name = uid, label = "{ %s | data %.4f | grad %.4f }" % (n.label, n.data, n.grad), shape='record')
    if n._op:
      # if this value is a result of some operation, create an op node for it
      dot.node(name = uid + n._op, label = n._op)
      # and connect this node to it
      dot.edge(uid + n._op, uid)

  for n1, n2 in edges:
    # connect n1 to the op node of n2
    dot.edge(str(id(n1)), str(id(n2)) + n2._op)

  return dot

# %%
class Value:
  def __init__(self, data):
    """1. grad 2. children for back propogation 3. label/name 4. operator"""
    pass

  def __repr__(self) -> str:
    """If __str__ is not defined in a class, __repr__ is used as a fallback
    for the informal string representation (e.g., when print() is called).
    """
    pass

  def __add__(self, other):
    pass

  def __mul__(self, other):
    pass

  def tanh(self):
    pass

  def backward(self):
    pass
